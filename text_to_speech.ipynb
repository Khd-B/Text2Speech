# %% [markdown]
# <a href="https://colab.research.google.com/github/Khd-B/Text2Speech/blob/main/text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
# Define text you want to convert to speech
text = "Hello! This is a text-to-speech test using Google Text-to-Speech."

# Create a gTTS object
tts = gTTS(text=text, lang='en')

# Save the audio file
tts.save("output.mp3")

# %%
# Play the generated audio
Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
